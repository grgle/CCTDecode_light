# %%
# %run CCTDecodeRelease.py --src_folder data --filename test.jpg --bit_n 12 --color black
# Out:
# Called with args:
# Namespace(batch=False, bit_n=12, color='black', filename='test.jpg', save_folder='./result/', src_folder='data', threshold=0.85)
# image path:  data\test.jpg
# box1: ((7796.626953125, 5536.130859375), (8.909594535827637, 12.096417427062988), 57.233795166015625)
# box2: ((7796.626953125, 5536.130859375), (19.601107978820803, 26.612118339538576), 57.233795166015625)
# box3: ((7796.626953125, 5536.130859375), (30.292621421813966, 41.127819252014156), 57.233795166015625)
# box1: ((7750.1318359375, 5514.28515625), (6.2955427169799805, 10.4306001663208), 40.83974838256836)
# box2: ((7750.1318359375, 5514.28515625), (13.850193977355959, 22.947320365905764), 40.83974838256836)
# box3: ((7750.1318359375, 5514.28515625), (21.404845237731934, 35.46404056549072), 40.83974838256836)
# box1: ((4411.037109375, 5011.6259765625), (69.96319580078125, 86.11426544189453), 33.64173126220703)
# ...
